# %%
import pandas as pd
import numpy as np
import re
import warnings

from geopy import Nominatim

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Pubs Data

# %%
#import all pubs csv for data wrangling
pubs_df = pd.read_csv("/content/raw-london-pubs.csv", index_col=[0])
pubs_detailed = pd.read_csv("/content/raw-london-pubs-detailed-data.csv", index_col=[0])

# %% [markdown]
# ### Cleaning Pubs data

# %%
# check raw pub core data
pubs_df.head()
# Out:
#                      fsq_id  \
# 0  4bc1e42eabf49521c690c193
# 1  4b995bccf964a5209f7535e3
# 2  4bb4da3fa7059521b8cc1bce
# 3  4dc436e5ae608779d11bd561
# 4  4d72b1e78e12b1f793863f05
#
#                                           categories  \
# 0  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 1  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 2  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 3  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 4  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
#
#                                             geocodes  \
# 0  {'main': {'latitude': 51.653075, 'longitude': ...
# 1  {'main': {'latitude': 51.652979, 'longitude': ...
# 2  {'main': {'latitude': 51.652533, 'longitude': ...
# 3  {'main': {'latitude': 51.650059, 'longitude': ...
# 4  {'main': {'latitude': 51.653499, 'longitude': ...
#
#                                             location                name
# 0  {'address': '92 Wood St', 'admin_region': 'Eng...     The Black Horse
# 1  {'address': '58 High St', 'admin_region': 'Eng...  Ye Olde Mitre Inne
# 2  {'address': 'Barnet Rd', 'admin_region': 'Engl...          The Arkley
# 3  {'address': '3 East Barnet Rd', 'admin_region'...      Railway Tavern
# 4  {'address': '84 High St', 'admin_region': 'Eng...      The Kings Head

# %%
# check duplicated rows of core pub dataframe
pubs_df.duplicated().value_counts()
# Out:
# False    1159
# True      569
# dtype: int64

# %%
# drop duplicated rows of core pub dataframe
pubs_df = pubs_df.drop_duplicates()
pubs_df.shape
# Out:
# (1159, 5)

# %%
# extract selected data from column with values in dictionaries
def extract_value(df, column, regex):
    return df[column].str.extract(regex)

# %%
pubs_df["geocodes"] = extract_value(pubs_df, "geocodes", "{'main':.\{(.*?)\}")
pubs_df["address"] = extract_value(pubs_df, "location", "{'address':.'(.*?)',")
pubs_df["locality"] = extract_value(pubs_df, "location", "'locality':.'(.*?)',")
pubs_df["neighborhood"] = extract_value(pubs_df, "location", "'neighborhood':.\['(.*)'\]")
pubs_df["postcode"] = extract_value(pubs_df, "location", "'postcode':.'(.*?)'")
pubs_df["category"] = extract_value(pubs_df, "categories", "'name':.'(.*?)'")

# %%
pubs_df.head()
# Out:
#                      fsq_id  \
# 0  4bc1e42eabf49521c690c193
# 1  4b995bccf964a5209f7535e3
# 2  4bb4da3fa7059521b8cc1bce
# 3  4dc436e5ae608779d11bd561
# 4  4d72b1e78e12b1f793863f05
#
#                                           categories  \
# 0  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 1  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 2  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 3  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 4  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
#
#                                         geocodes  \
# 0  'latitude': 51.653075, 'longitude': -0.206657
# 1  'latitude': 51.652979, 'longitude': -0.199367
# 2  'latitude': 51.652533, 'longitude': -0.219573
# 3  'latitude': 51.650059, 'longitude': -0.174692
# 4  'latitude': 51.653499, 'longitude': -0.200979
#
#                                             location                name  \
# 0  {'address': '92 Wood St', 'admin_region': 'Eng...     The Black Horse
# 1  {'address': '58 High St', 'admin_region': 'Eng...  Ye Olde Mitre Inne
# 2  {'address': 'Barnet Rd', 'admin_region': 'Engl...          The Arkley
# 3  {'address': '3 East Barnet Rd', 'admin_region'...      Railway Tavern
# 4  {'address': '84 High St', 'admin_region': 'Eng...      The Kings Head
#
#             address       locality neighborhood postcode category
# 0        92 Wood St         London       Barnet  EN5 4BW      Pub
# 1        58 High St  Hertfordshire       Barnet  EN5 5SJ      Pub
# 2         Barnet Rd         Barnet       Barnet  EN5 3EP      Pub
# 3  3 East Barnet Rd         Barnet       Barnet  EN4 8RR      Pub
# 4        84 High St         Barnet       Barnet  EN5 5SN      Pub

# %%
# check for null values in geocodes column
pubs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1159 entries, 0 to 1724
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   fsq_id        1159 non-null   object
#  1   categories    1159 non-null   object
#  2   geocodes      1142 non-null   object
#  3   location      1159 non-null   object
#  4   name          1159 non-null   object
#  5   address       1115 non-null   object
#  6   locality      1134 non-null   object
#  7   neighborhood  989 non-null    object
#  8   postcode      1154 non-null   object
#  9   category      1159 non-null   object
# dtypes: object(10)
# memory usage: 99.6+ KB

# %%
pubs_df["geocodes"].isnull().sum()
empty_geocodes = pubs_df[pubs_df["geocodes"].isnull()]

# %%
# get coordinate to fill the null values in the geocodes column
geolocator = Nominatim(user_agent="women_safety")

# %%
def get_geocodes():
    for col, row in empty_geocodes.iterrows():
        get_geocodes_by_street(row)


# try to find coordinates from addres
def get_geocodes_by_street(row):
    address = row["address"]
    try:
        location = geolocator.geocode(f"{address}, London")
        row[
            "geocodes"
        ] = f"'latitude': {location.latitude}, 'longitude': {location.longitude}"
    except:
        get_geocodes_by_postcode(row)


# try to find coordinates from postcode
def get_geocodes_by_postcode(row):
    id = row["fsq_id"]
    try:
        location = geolocator.geocode(row["postcode"])
        row[
            "geocodes"
        ] = f"'latitude': {location.latitude}, 'longitude': {location.longitude}"
    except:
        row["geocodes"] = np.nan
        print(f"It was not possible to find coordinates for {id}")

# %%
# get missing geocodes using geopy library
get_geocodes()

# %%
# check for missing data
print(empty_geocodes["geocodes"].isnull().sum())
# Out:
# 0

# %%
# assign the geocodes found to the main dataframe
pubs_df["geocodes"][pubs_df["geocodes"].isnull()] = empty_geocodes["geocodes"]
print(pubs_df["geocodes"].isnull().sum())
# Out:
# 0

# %%
#find empty string in the postcode column and replace with numpy nan
pubs_df["postcode"][pubs_df["postcode"] == ""] = np.nan

# %%
# divide the geocode column into two new columns: latitude and longitude
def get_lat_long(df):
    lat_list = []
    long_list = []
    geocodes_split = df["geocodes"].str.split(",")
    for lat, longi in geocodes_split:
        lat = re.search("latitude':.(.*)", lat).group(1)
        lat_list.append(lat)
        longi = re.search("longitude':.(.*)", longi).group(1)
        long_list.append(longi)
    df["latitude"] = lat_list
    df["longitude"] = long_list

# %%
get_lat_long(pubs_df)

# %%
pubs_df.head()
# Out:
#                      fsq_id  \
# 0  4bc1e42eabf49521c690c193
# 1  4b995bccf964a5209f7535e3
# 2  4bb4da3fa7059521b8cc1bce
# 3  4dc436e5ae608779d11bd561
# 4  4d72b1e78e12b1f793863f05
#
#                                           categories  \
# 0  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 1  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 2  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 3  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
# 4  [{'id': 13018, 'name': 'Pub', 'icon': {'prefix...
#
#                                         geocodes  \
# 0  'latitude': 51.653075, 'longitude': -0.206657
# 1  'latitude': 51.652979, 'longitude': -0.199367
# 2  'latitude': 51.652533, 'longitude': -0.219573
# 3  'latitude': 51.650059, 'longitude': -0.174692
# 4  'latitude': 51.653499, 'longitude': -0.200979
#
#                                             location                name  \
# 0  {'address': '92 Wood St', 'admin_region': 'Eng...     The Black Horse
# 1  {'address': '58 High St', 'admin_region': 'Eng...  Ye Olde Mitre Inne
# 2  {'address': 'Barnet Rd', 'admin_region': 'Engl...          The Arkley
# 3  {'address': '3 East Barnet Rd', 'admin_region'...      Railway Tavern
# 4  {'address': '84 High St', 'admin_region': 'Eng...      The Kings Head
#
#             address       locality neighborhood postcode category   latitude  \
# 0        92 Wood St         London       Barnet  EN5 4BW      Pub  51.653075
# 1        58 High St  Hertfordshire       Barnet  EN5 5SJ      Pub  51.652979
# 2         Barnet Rd         Barnet       Barnet  EN5 3EP      Pub  51.652533
# 3  3 East Barnet Rd         Barnet       Barnet  EN4 8RR      Pub  51.650059
# 4        84 High St         Barnet       Barnet  EN5 5SN      Pub  51.653499
#
#    longitude
# 0  -0.206657
# 1  -0.199367
# 2  -0.219573
# 3  -0.174692
# 4  -0.200979

# %%
# drop columns that will not be use in this project
pubs_df = pubs_df.drop(columns=["categories", "geocodes", "location"], axis=1)

# %%
pubs_df.head()
# Out:
#                      fsq_id                name           address  \
# 0  4bc1e42eabf49521c690c193     The Black Horse        92 Wood St
# 1  4b995bccf964a5209f7535e3  Ye Olde Mitre Inne        58 High St
# 2  4bb4da3fa7059521b8cc1bce          The Arkley         Barnet Rd
# 3  4dc436e5ae608779d11bd561      Railway Tavern  3 East Barnet Rd
# 4  4d72b1e78e12b1f793863f05      The Kings Head        84 High St
#
#         locality neighborhood postcode category   latitude  longitude
# 0         London       Barnet  EN5 4BW      Pub  51.653075  -0.206657
# 1  Hertfordshire       Barnet  EN5 5SJ      Pub  51.652979  -0.199367
# 2         Barnet       Barnet  EN5 3EP      Pub  51.652533  -0.219573
# 3         Barnet       Barnet  EN4 8RR      Pub  51.650059  -0.174692
# 4         Barnet       Barnet  EN5 5SN      Pub  51.653499  -0.200979

# %% [markdown]
# ### Cleaning detailed data and merging all pubs data into one dataframe

# %%
# check pubs detailed data dataframe
pubs_detailed.head()
# Out:
#                      fsq_id  popularity  price  rating
# 0  4bc1e42eabf49521c690c193    0.939551    1.0     8.1
# 1  4b995bccf964a5209f7535e3    0.982768    1.0     7.6
# 2  4bb4da3fa7059521b8cc1bce    0.987375    1.0     7.7
# 3  4dc436e5ae608779d11bd561    0.950895    1.0     7.4
# 4  4d72b1e78e12b1f793863f05    0.377777    1.0     6.6

# %%
# check for duplicated data
pubs_detailed.duplicated().value_counts()
# Out:
# False    1159
# True      569
# dtype: int64

# %%
# drop the duplicated rows
pubs_detailed = pubs_detailed.drop_duplicates()

# %%
#check if the two dataframe have the same number of rows
print(pubs_df.shape)
print(pubs_detailed.shape)
# Out:
# (1159, 9)
# (1159, 4)

# %%
# merge the pubs updated dataframe with the pubs detailed data dataframe
pubs_data = pubs_df.merge(pubs_detailed, how="left", on="fsq_id")

# %%
pubs_data.head()
# Out:
#                      fsq_id                name           address  \
# 0  4bc1e42eabf49521c690c193     The Black Horse        92 Wood St
# 1  4b995bccf964a5209f7535e3  Ye Olde Mitre Inne        58 High St
# 2  4bb4da3fa7059521b8cc1bce          The Arkley         Barnet Rd
# 3  4dc436e5ae608779d11bd561      Railway Tavern  3 East Barnet Rd
# 4  4d72b1e78e12b1f793863f05      The Kings Head        84 High St
#
#         locality neighborhood postcode category   latitude  longitude  \
# 0         London       Barnet  EN5 4BW      Pub  51.653075  -0.206657
# 1  Hertfordshire       Barnet  EN5 5SJ      Pub  51.652979  -0.199367
# 2         Barnet       Barnet  EN5 3EP      Pub  51.652533  -0.219573
# 3         Barnet       Barnet  EN4 8RR      Pub  51.650059  -0.174692
# 4         Barnet       Barnet  EN5 5SN      Pub  51.653499  -0.200979
#
#    popularity  price  rating
# 0    0.939551    1.0     8.1
# 1    0.982768    1.0     7.6
# 2    0.987375    1.0     7.7
# 3    0.950895    1.0     7.4
# 4    0.377777    1.0     6.6

# %%
pubs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1159 entries, 0 to 1158
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   fsq_id        1159 non-null   object
#  1   name          1159 non-null   object
#  2   address       1115 non-null   object
#  3   locality      1134 non-null   object
#  4   neighborhood  989 non-null    object
#  5   postcode      1114 non-null   object
#  6   category      1159 non-null   object
#  7   latitude      1159 non-null   object
#  8   longitude     1159 non-null   object
#  9   popularity    1159 non-null   float64
#  10  price         1143 non-null   float64
#  11  rating        865 non-null    float64
# dtypes: float64(3), object(9)
# memory usage: 117.7+ KB

# %% [markdown]
# ### Resolving missing values

# %%
pubs_data.isnull().sum()
# Out:
# fsq_id            0
# name              0
# address          44
# locality         25
# neighborhood    170
# postcode         45
# category          0
# latitude          0
# longitude         0
# popularity        0
# price            16
# rating          294
# dtype: int64

# %%
#drop rows with null values in rating
pubs_data.dropna(subset=["rating"], axis=0, inplace=True)

# %%
pubs_data.shape
# Out:
# (865, 12)

# %%
#assign mode to missing values in price
pubs_data["price"].value_counts()
# Out:
# 1.0    698
# 2.0    141
# 3.0     13
# Name: price, dtype: int64

# %%
pubs_data["price"].fillna(1, inplace=True)

# %%
pubs_data[pubs_data["postcode"].isnull()]
# Out:
#                        fsq_id                        name        address  \
# 5    4c0bab78ffb8c9b6e9886d61             The Monken Holt
# 593  4f2188efe4b0cebcfb6406aa  Ortaköy, Shisha Lounge Bar    83 Mayes Rd
# 674  4c653ed03f69c9b6fea28ad9         The General Elliott
# 808  4c75413c1b30a09338c4ee09             The Limping Fox     Rushett Rd
# 818  562d09d4498eb208288dda65             The Railway Pub  3 Victoria Rd
#
#         locality   neighborhood postcode category   latitude  longitude  \
# 5            NaN  Monken Hadley      NaN      Pub  51.658291  -0.201368
# 593       London            NaN      NaN      Pub  51.594699  -0.112428
# 674          NaN            NaN      NaN      Pub  51.542912  -0.488453
# 808  Long Ditton            NaN      NaN      Pub  51.386031  -0.323829
# 818       London            NaN      NaN      Pub  51.424276  -0.332793
#
#      popularity  price  rating
# 5      0.246146    1.0     6.8
# 593    0.926055    1.0     6.7
# 674    0.913205    1.0     7.6
# 808    0.990826    1.0     7.5
# 818    0.916892    1.0     6.9

# %%
pubs_data.loc[5, "postcode"] = "EN5 5SU"

# %%
pubs_data.loc[593, "postcode"] = "N22 6UP"

# %%
pubs_data.loc[674, "postcode"] = "UB8 2UR"

# %%
pubs_data.loc[808, "postcode"] = "KT7 0UX"

# %%
pubs_data.loc[818, "postcode"] = "TW11 0BB"

# %%
#drop columns that will not be used anymore
pubs_data.drop(columns=["address", "locality", "neighborhood", "category", "fsq_id"], inplace=True)

# %%
pubs_data.head(10)
# Out:
#                   name postcode   latitude  longitude  popularity  price  \
# 0      The Black Horse  EN5 4BW  51.653075  -0.206657    0.939551    1.0
# 1   Ye Olde Mitre Inne  EN5 5SJ  51.652979  -0.199367    0.982768    1.0
# 2           The Arkley  EN5 3EP  51.652533  -0.219573    0.987375    1.0
# 3       Railway Tavern  EN4 8RR  51.650059  -0.174692    0.950895    1.0
# 4       The Kings Head  EN5 5SN  51.653499  -0.200979    0.377777    1.0
# 5      The Monken Holt  EN5 5SU  51.658291  -0.201368    0.246146    1.0
# 6     The Green Dragon  EN5 4RE  51.674789  -0.216312    0.972166    1.0
# 7         The Red Lion  EN5 5UW  51.652453  -0.199044    0.967387    1.0
# 8      The Orange Tree  N20 8NX  51.629934  -0.197419    0.951498    1.0
# 12         Queens Arms  EN5 1AB   51.64669  -0.188042    0.888001    1.0
#
#     rating
# 0      8.1
# 1      7.6
# 2      7.7
# 3      7.4
# 4      6.6
# 5      6.8
# 6      7.2
# 7      6.1
# 8      6.5
# 12     5.6

# %%
pubs_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 865 entries, 0 to 1157
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        865 non-null    object
#  1   postcode    865 non-null    object
#  2   latitude    865 non-null    object
#  3   longitude   865 non-null    object
#  4   popularity  865 non-null    float64
#  5   price       865 non-null    float64
#  6   rating      865 non-null    float64
# dtypes: float64(3), object(4)
# memory usage: 86.4+ KB

# %%
#saving cleaned data for the next stage
pubs_data.to_csv("data-wrangling-pubs-data.csv")

# %% [markdown]
# ## Police data

# %%
police_df = pd.read_csv("/content/raw-london-police-station-data.csv", index_col=[0])

# %%
police_df.head()
# Out:
#                      fsq_id  \
# 0  4f75c889e4b0b24b0c1c4c98
# 1  886e605708d446fd6af7be02
# 2  7687cbfe5d9743d0bcfd91b6
# 3  dd8ab317b29242cec99126f6
# 4  fa389098b2a249fb9381e3f3
#
#                                           categories  \
# 0  [{'id': 12072, 'name': 'Police Station', 'icon...
# 1  [{'id': 12072, 'name': 'Police Station', 'icon...
# 2  [{'id': 12072, 'name': 'Police Station', 'icon...
# 3  [{'id': 12072, 'name': 'Police Station', 'icon...
# 4  [{'id': 12072, 'name': 'Police Station', 'icon...
#
#                                             geocodes  \
# 0  {'main': {'latitude': 51.652283, 'longitude': ...
# 1  {'main': {'latitude': 51.654345, 'longitude': ...
# 2  {'main': {'latitude': 51.655584, 'longitude': ...
# 3  {'main': {'latitude': 51.64317, 'longitude': -...
# 4  {'main': {'latitude': 51.643139, 'longitude': ...
#
#                                             location  \
# 0  {'address': '26-32 High St', 'admin_region': '...
# 1  {'admin_region': 'England', 'country': 'GB', '...
# 2  {'address': '111 High St', 'admin_region': 'En...
# 3  {'address': 'Snt Base, 13 Cat Hill', 'admin_re...
# 4  {'address': '13 Cat Hill', 'admin_region': 'En...
#
#                           name
# 0        Barnet Police Station
# 1        Barnet Police Station
# 2          Metropolitan Police
# 3                     Cat Hill
# 4  Metropolitan Police Service

# %%
# check for duplicated rows
police_df.duplicated().value_counts()
# Out:
# False    246
# True     224
# dtype: int64

# %%
# drop duplicated rows
police_df = police_df.drop_duplicates()

# %%
# extract selected data from column with values in dictionaries
police_df["geocodes"] = extract_value(police_df, "geocodes", "{'main':.\{(.*?)\}")
police_df["address"] = extract_value(police_df, "location", "{'address':.'(.*?)',")
police_df["locality"] = extract_value(police_df, "location", "'locality':.'(.*?)',")
police_df["neighborhood"] = extract_value(police_df, "location", "'neighborhood':.\['(.*)'\]")
police_df["postcode"] = extract_value(police_df, "location", "'postcode':.'(.*?)'")
police_df["category"] = extract_value(police_df, "categories", "'name':.'(.*?)'")

# %%
police_df.head()
# Out:
#                      fsq_id  \
# 0  4f75c889e4b0b24b0c1c4c98
# 1  886e605708d446fd6af7be02
# 2  7687cbfe5d9743d0bcfd91b6
# 3  dd8ab317b29242cec99126f6
# 4  fa389098b2a249fb9381e3f3
#
#                                           categories  \
# 0  [{'id': 12072, 'name': 'Police Station', 'icon...
# 1  [{'id': 12072, 'name': 'Police Station', 'icon...
# 2  [{'id': 12072, 'name': 'Police Station', 'icon...
# 3  [{'id': 12072, 'name': 'Police Station', 'icon...
# 4  [{'id': 12072, 'name': 'Police Station', 'icon...
#
#                                         geocodes  \
# 0  'latitude': 51.652283, 'longitude': -0.198046
# 1  'latitude': 51.654345, 'longitude': -0.201383
# 2  'latitude': 51.655584, 'longitude': -0.202649
# 3   'latitude': 51.64317, 'longitude': -0.162268
# 4  'latitude': 51.643139, 'longitude': -0.161936
#
#                                             location  \
# 0  {'address': '26-32 High St', 'admin_region': '...
# 1  {'admin_region': 'England', 'country': 'GB', '...
# 2  {'address': '111 High St', 'admin_region': 'En...
# 3  {'address': 'Snt Base, 13 Cat Hill', 'admin_re...
# 4  {'address': '13 Cat Hill', 'admin_region': 'En...
#
#                           name                address locality neighborhood  \
# 0        Barnet Police Station          26-32 High St   Barnet       Barnet
# 1        Barnet Police Station                    NaN   London          NaN
# 2          Metropolitan Police            111 High St   Barnet          NaN
# 3                     Cat Hill  Snt Base, 13 Cat Hill   Barnet          NaN
# 4  Metropolitan Police Service            13 Cat Hill   Barnet          NaN
#
#   postcode        category
# 0  EN5 5RU  Police Station
# 1      NaN  Police Station
# 2  EN5 5XY  Police Station
# 3  EN4 8HG  Police Station
# 4  EN4 8HG  Police Station

# %%
# check for missing data
police_df[police_df["geocodes"].isnull()]
# Out:
#                       fsq_id  \
# 50  52e92a52498e8f6d4ed62bfc
#
#                                            categories geocodes  \
# 50  [{'id': 12072, 'name': 'Police Station', 'icon...      NaN
#
#                                              location  \
# 50  {'address': '109 Lambeth Rd', 'admin_region': ...
#
#                                                  name         address  \
# 50  Metropolitan Police Central Communications Com...  109 Lambeth Rd
#
#    locality neighborhood postcode        category
# 50   London          NaN  SE1 7JP  Police Station

# %%
# assign the geocedes data missing
location = geolocator.geocode("109 Lambeth Rd, London")
police_df.loc[
    50, "geocodes"
] = f"'latitude': {location.latitude}, 'longitude': {location.longitude}"

# %%
police_df.loc[50, "geocodes"]
# Out:
# "'latitude': 51.49420595, 'longitude': -0.11762509407853665"

# %%
##divide the geocode column into two new columns: latitude and longitude
get_lat_long(police_df)

# %%
police_df.head()
# Out:
#                      fsq_id  \
# 0  4f75c889e4b0b24b0c1c4c98
# 1  886e605708d446fd6af7be02
# 2  7687cbfe5d9743d0bcfd91b6
# 3  dd8ab317b29242cec99126f6
# 4  fa389098b2a249fb9381e3f3
#
#                                           categories  \
# 0  [{'id': 12072, 'name': 'Police Station', 'icon...
# 1  [{'id': 12072, 'name': 'Police Station', 'icon...
# 2  [{'id': 12072, 'name': 'Police Station', 'icon...
# 3  [{'id': 12072, 'name': 'Police Station', 'icon...
# 4  [{'id': 12072, 'name': 'Police Station', 'icon...
#
#                                         geocodes  \
# 0  'latitude': 51.652283, 'longitude': -0.198046
# 1  'latitude': 51.654345, 'longitude': -0.201383
# 2  'latitude': 51.655584, 'longitude': -0.202649
# 3   'latitude': 51.64317, 'longitude': -0.162268
# 4  'latitude': 51.643139, 'longitude': -0.161936
#
#                                             location  \
# 0  {'address': '26-32 High St', 'admin_region': '...
# 1  {'admin_region': 'England', 'country': 'GB', '...
# 2  {'address': '111 High St', 'admin_region': 'En...
# 3  {'address': 'Snt Base, 13 Cat Hill', 'admin_re...
# 4  {'address': '13 Cat Hill', 'admin_region': 'En...
#
#                           name                address locality neighborhood  \
# 0        Barnet Police Station          26-32 High St   Barnet       Barnet
# 1        Barnet Police Station                    NaN   London          NaN
# 2          Metropolitan Police            111 High St   Barnet          NaN
# 3                     Cat Hill  Snt Base, 13 Cat Hill   Barnet          NaN
# 4  Metropolitan Police Service            13 Cat Hill   Barnet          NaN
#
#   postcode        category   latitude  longitude
# 0  EN5 5RU  Police Station  51.652283  -0.198046
# 1      NaN  Police Station  51.654345  -0.201383
# 2  EN5 5XY  Police Station  51.655584  -0.202649
# 3  EN4 8HG  Police Station   51.64317  -0.162268
# 4  EN4 8HG  Police Station  51.643139  -0.161936

# %%
# drop columns that will not be use in this project
police_df = police_df.drop(columns=["categories", "geocodes", "location"], axis=1)

# %%
police_df.head()
# Out:
#                      fsq_id                         name  \
# 0  4f75c889e4b0b24b0c1c4c98        Barnet Police Station
# 1  886e605708d446fd6af7be02        Barnet Police Station
# 2  7687cbfe5d9743d0bcfd91b6          Metropolitan Police
# 3  dd8ab317b29242cec99126f6                     Cat Hill
# 4  fa389098b2a249fb9381e3f3  Metropolitan Police Service
#
#                  address locality neighborhood postcode        category  \
# 0          26-32 High St   Barnet       Barnet  EN5 5RU  Police Station
# 1                    NaN   London          NaN      NaN  Police Station
# 2            111 High St   Barnet          NaN  EN5 5XY  Police Station
# 3  Snt Base, 13 Cat Hill   Barnet          NaN  EN4 8HG  Police Station
# 4            13 Cat Hill   Barnet          NaN  EN4 8HG  Police Station
#
#     latitude  longitude
# 0  51.652283  -0.198046
# 1  51.654345  -0.201383
# 2  51.655584  -0.202649
# 3   51.64317  -0.162268
# 4  51.643139  -0.161936

# %%
# save dataframe into csv
police_df.to_csv("data-wrangling-police_data.csv")
